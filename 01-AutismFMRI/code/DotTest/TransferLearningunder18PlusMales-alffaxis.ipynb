# %%
# # CNN FINETUNING WITH PRE-TRAINED VGG NET - Small Training Size
# %matplotlib inline
import os
import numpy as np
import tensorflow as tf
import load_fmri_alff_dottest_transferlearning_axis as input_data
import matplotlib.pyplot as plt
import scipy.misc
import scipy.io
#from tensorflow.examples.tutorials.mnist import input_data

# Load Data
fmri = input_data.read_data_sets("../data/AllSubjects4cat.hdf5", fraction=1, channels=1)
trainimg   = fmri.train.images
trainlabel = fmri.train.labels
testimg    = fmri.test.images
testlabel  = fmri.test.labels
ntrain      = trainimg.shape[0]
ntest       = testimg.shape[0]
dim         = trainimg.shape[1]
nout        = trainlabel.shape[1]

print ("%d train images loaded" % (ntrain))
print ("%d test images loaded" % (ntest))
print ("%d dimensional input" % (dim))
# print ("%d classes" % (nclass))
print ("shape of 'trainimg' is %s" % (trainimg.shape,))
print ("shape of 'testimg' is %s" % (testimg.shape,))

print (trainlabel.shape)
# Out:
# Loading Training Imagery...
# .....................
# Loading Test Imagery...
# .......204 train images loaded
# 69 test images loaded
# 10800 dimensional input
# shape of 'trainimg' is (204, 10800)
# shape of 'testimg' is (69, 10800)
# (204, 2)

# %%
img = np.reshape(testimg[9],(60,60,3) )
np.max(img[:,:,0])
# Out:
# 1.0

# %%
img = np.reshape(testimg[27],(60,60,3) )
plt.imshow(img[:,:,:])
plt.axis("off")
# Out:
# (-0.5, 59.5, 59.5, -0.5)

# %%
trainimg_tensor = np.ndarray((ntrain, 60, 60, 3))
for i in range(ntrain):
    currimg = trainimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    trainimg_tensor[i, :, :, :] = currimg
print ("shape of trainimg_tensor is %s" % (trainimg_tensor.shape,))

testimg_tensor = np.ndarray((ntest, 60, 60, 3))
for i in range(ntest):
    currimg = testimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    testimg_tensor[i, :, :, :] = currimg
print ("shape of testimg_tensor is %s" % (testimg_tensor.shape,))
# Out:
# shape of trainimg_tensor is (204, 60, 60, 3)
# shape of testimg_tensor is (69, 60, 60, 3)

# %%
# # DEFINE A FUNCTION FOR USING PRETRAINED VGG NETWORK

def net(data_path, input_image):
    layers = (
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1',
        'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3',
        'relu3_3', 'conv3_4', 'relu3_4', 'pool3',
        'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'conv4_3',
        'relu4_3', 'conv4_4', 'relu4_4', 'pool4',
        'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'conv5_3',
        'relu5_3', 'conv5_4', 'relu5_4'
    )
    data = scipy.io.loadmat(data_path)
    mean = data['normalization'][0][0][0]
    mean_pixel = np.mean(mean, axis=(0, 1))
    weights = data['layers'][0]
    net = {}
    current = input_image
    for i, name in enumerate(layers):
        kind = name[:4]
        if kind == 'conv':
            kernels, bias = weights[i][0][0][0][0]
            # matconvnet: weights are [width, height, in_channels, out_channels]
            # tensorflow: weights are [height, width, in_channels, out_channels]
            kernels = np.transpose(kernels, (1, 0, 2, 3))
            bias = bias.reshape(-1)
            current = _conv_layer(current, kernels, bias)
        elif kind == 'relu':
            current = tf.nn.relu(current)
        elif kind == 'pool':
            current = _pool_layer(current)
        net[name] = current

    assert len(net) == len(layers)
    return net, mean_pixel
with tf.device("/cpu:0"):
    def _conv_layer(input, weights, bias):
        conv = tf.nn.conv2d(input, tf.constant(weights), strides=(1, 1, 1, 1),
                            padding='SAME')
        return tf.nn.bias_add(conv, bias)

    def _pool_layer(input):
        return tf.nn.max_pool(input, ksize=(1, 2, 2, 1), strides=(1, 2, 2, 1),
                              padding='SAME')

    def preprocess(image, mean_pixel):
        return image - mean_pixel

    def unprocess(image, mean_pixel):
        return image + mean_pixel

# %%
## EXTRACT FEATURES FROM THE VGG NETWORK
cwd = os.getcwd()
VGG_PATH = cwd + "/data/imagenet-vgg-verydeep-19.mat"
with tf.Graph().as_default(), tf.Session() as sess:
    with tf.device("/cpu:0"):
        img_placeholder = tf.placeholder(tf.float32, shape=(None, 60, 60, 3))
        net_val, mean_pixel = net(VGG_PATH, img_placeholder)
        train_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: trainimg_tensor})
        print("Train Features finished...")
        test_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: testimg_tensor})
print ("TYPE OF 'train_features' IS %s" % (type(train_features)))
print ("SHAPE OF 'train_features' IS %s" % (train_features.shape,))
print ("TYPE OF 'test_features' IS %s" % (type(test_features)))
print ("SHAPE OF 'test_features' IS %s" % (test_features.shape,))
print("PREPROCESSING DONE")
# Out:
# Train Features finished...
# TYPE OF 'train_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'train_features' IS (204, 4, 4, 512)
# TYPE OF 'test_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'test_features' IS (69, 4, 4, 512)
# PREPROCESSING DONE

# %%
# # VECTORIZE CNN FEATURES

train_vectorized = np.ndarray((ntrain, 8192))
test_vectorized = np.ndarray((ntest, 8192))
for i in range(ntrain):
    curr_feat = train_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    train_vectorized[i, :] = curr_feat_vec

for i in range(ntest):
    curr_feat = test_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    test_vectorized[i, :] = curr_feat_vec

print ("SHAPE OF 'train_vectorized' IS %s" % (train_vectorized.shape,))
print ("SHAPE OF 'test_vectorized' IS %s" % (test_vectorized.shape,))

# # DEFINE NETWORKS AND FUNCTIONS (ADD 2LAYER MLP)
# Out:
# SHAPE OF 'train_vectorized' IS (204, 8192)
# SHAPE OF 'test_vectorized' IS (69, 8192)

# %%
# Parameters
learning_rate = 0.00001  # default 0.0001
training_epochs = 300
batch_size = 10  # default 100
display_step = 3

# %%
# Network
with tf.device("/cpu:0"):
    n_input = dim
    n_output = 2
    # n_output = nclass
    weights = {
        'wd1': tf.Variable(tf.random_normal([8192, 1024], stddev=0.1)),
        'wd2': tf.Variable(tf.random_normal([1024, n_output], stddev=0.1))
    }
    biases = {
        'bd1': tf.Variable(tf.random_normal([1024], stddev=0.1)),
        'bd2': tf.Variable(tf.random_normal([n_output], stddev=0.1))
    }


    def conv_basic(_input, _w, _b, _keepratio):
        # Input
        _input_r = _input
        # Vectorize
        _dense1 = tf.reshape(_input_r, [-1, _w['wd1'].get_shape().as_list()[0]])
        # Fc1
        _fc1 = tf.nn.relu(tf.add(tf.matmul(_dense1, _w['wd1']), _b['bd1']))
        _fc_dr1 = tf.nn.dropout(_fc1, _keepratio)
        # Fc2
        _out = tf.add(tf.matmul(_fc_dr1, _w['wd2']), _b['bd2'])
        # Return everything
        out = {'input_r': _input_r, 'dense1': _dense1,
               'fc1': _fc1, 'fc_dr1': _fc_dr1, 'out': _out}
        return out

# tf Graph input
x = tf.placeholder(tf.float32, [None, 8192])
y = tf.placeholder(tf.float32, [None, n_output])
keepratio = tf.placeholder(tf.float32)

# %%
# Functions!
with tf.device("/cpu:0"):
    _pred = conv_basic(x, weights, biases, keepratio)['out']
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(_pred, y))
    optm = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    _corr = tf.equal(tf.argmax(_pred, 1), tf.argmax(y, 1))  # Count corrects
    accr = tf.reduce_mean(tf.cast(_corr, tf.float32))  # Accuracy
    init = tf.initialize_all_variables()

print ("Network Ready to Go!")
# Out:
# Network Ready to Go!

# %%
testing = []
training = []

with tf.device("/cpu:0"):
    sess = tf.Session()
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        num_batch = int(ntrain / batch_size) + 1
        # Loop over all batches
        for i in range(num_batch):
            randidx = np.random.randint(ntrain, size=batch_size)
            batch_xs = train_vectorized[randidx, :]
            batch_ys = trainlabel[randidx, :]
            # Fit training using batch data
            sess.run(optm, feed_dict={x: batch_xs, y: batch_ys, keepratio: 0.7})
            # Compute average loss
            avg_cost += sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.}) / num_batch

        # Display logs per epoch step
        if epoch % display_step == 0:
            print ("Epoch: %03d/%03d cost: %.9f" % (epoch, training_epochs, avg_cost))
            train_acc = sess.run(accr, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.})
            print (" Training accuracy: %.3f" % (train_acc))
            training.append(train_acc)
            test_acc = sess.run(accr, feed_dict={x: test_vectorized, y: testlabel, keepratio: 1.})
            print (" Test accuracy: %.3f" % (test_acc))
            testing.append(test_acc)

print ("Optimization Finished!")
# Out:
# Epoch: 000/300 cost: 12.407423224
#  Training accuracy: 0.400
#  Test accuracy: 0.522
# Epoch: 003/300 cost: 2.035298597
#  Training accuracy: 0.600
#  Test accuracy: 0.565
# Epoch: 006/300 cost: 1.261401713
#  Training accuracy: 0.500
#  Test accuracy: 0.536
# Epoch: 009/300 cost: 1.192466642
#  Training accuracy: 0.600
#  Test accuracy: 0.565
# Epoch: 012/300 cost: 1.199432211
#  Training accuracy: 0.500
#  Test accuracy: 0.536
# Epoch: 015/300 cost: 0.940254572
#  Training accuracy: 0.800
#  Test accuracy: 0.536
# Epoch: 018/300 cost: 1.139653476
#  Training accuracy: 0.400
#  Test accuracy: 0.565
# Epoch: 021/300 cost: 0.786900506
#  Training accuracy: 0.500
#  Test accuracy: 0.551
# Epoch: 024/300 cost: 0.984788121
#  Training accuracy: 0.600
#  Test accuracy: 0.536
# Epoch: 027/300 cost: 0.967539814
#  Training accuracy: 0.400
#  Test accuracy: 0.551
# Epoch: 030/300 cost: 0.867370892
#  Training accuracy: 0.700
#  Test accuracy: 0.522
# Epoch: 033/300 cost: 0.839213221
#  Training accuracy: 0.600
#  Test accuracy: 0.478
# Epoch: 036/300 cost: 0.940285805
#  Training accuracy: 0.700
#  Test accuracy: 0.551
# Epoch: 039/300 cost: 0.950027694
#  Training accuracy: 0.500
#  Test accuracy: 0.522
# Epoch: 042/300 cost: 0.905373448
#  Training accuracy: 0.700
#  Test accuracy: 0.522
# Epoch: 045/300 cost: 0.765880707
#  Training accuracy: 0.800
#  Test accuracy: 0.551
# Epoch: 048/300 cost: 1.016756640
#  Training accuracy: 0.500
#  Test accuracy: 0.522
# Epoch: 051/300 cost: 0.957827084
#  Training accuracy: 0.900
#  Test accuracy: 0.536
# Epoch: 054/300 cost: 0.916198858
#  Training accuracy: 0.600
#  Test accuracy: 0.565
# Epoch: 057/300 cost: 0.730460739
#  Training accuracy: 0.800
#  Test accuracy: 0.522
# Epoch: 060/300 cost: 0.784101820
#  Training accuracy: 0.600
#  Test accuracy: 0.580
# Epoch: 063/300 cost: 0.803065604
#  Training accuracy: 0.900
#  Test accuracy: 0.580
# Epoch: 066/300 cost: 0.791182465
#  Training accuracy: 0.900
#  Test accuracy: 0.551
# Epoch: 069/300 cost: 0.847351318
#  Training accuracy: 0.800
#  Test accuracy: 0.580
# Epoch: 072/300 cost: 0.929105329
#  Training accuracy: 0.200
#  Test accuracy: 0.522
# Epoch: 075/300 cost: 0.742100162
#  Training accuracy: 0.500
#  Test accuracy: 0.536
# Epoch: 078/300 cost: 0.900883731
#  Training accuracy: 0.800
#  Test accuracy: 0.594
# Epoch: 081/300 cost: 0.754503893
#  Training accuracy: 0.400
#  Test accuracy: 0.623
# Epoch: 084/300 cost: 0.920858076
#  Training accuracy: 0.600
#  Test accuracy: 0.580
# Epoch: 087/300 cost: 0.645217717
#  Training accuracy: 0.900
#  Test accuracy: 0.565
# Epoch: 090/300 cost: 0.621381257
#  Training accuracy: 0.300
#  Test accuracy: 0.594
# Epoch: 093/300 cost: 0.670786956
#  Training accuracy: 0.500
#  Test accuracy: 0.594
# Epoch: 096/300 cost: 0.698630123
#  Training accuracy: 0.700
#  Test accuracy: 0.565
# Epoch: 099/300 cost: 0.716365572
#  Training accuracy: 0.400
#  Test accuracy: 0.667
# Epoch: 102/300 cost: 0.598211141
#  Training accuracy: 0.700
#  Test accuracy: 0.652
# Epoch: 105/300 cost: 0.826490651
#  Training accuracy: 0.800
#  Test accuracy: 0.609
# Epoch: 108/300 cost: 0.613963773
#  Training accuracy: 0.600
#  Test accuracy: 0.638
# Epoch: 111/300 cost: 0.516319401
#  Training accuracy: 0.800
#  Test accuracy: 0.580
# Epoch: 114/300 cost: 0.808639551
#  Training accuracy: 0.500
#  Test accuracy: 0.580
# Epoch: 117/300 cost: 0.648273528
#  Training accuracy: 0.900
#  Test accuracy: 0.565
# Epoch: 120/300 cost: 0.639086347
#  Training accuracy: 0.800
#  Test accuracy: 0.594
# Epoch: 123/300 cost: 0.549124630
#  Training accuracy: 0.700
#  Test accuracy: 0.609
# Epoch: 126/300 cost: 0.661343264
#  Training accuracy: 0.500
#  Test accuracy: 0.580
# Epoch: 129/300 cost: 0.496646980
#  Training accuracy: 0.800
#  Test accuracy: 0.623
# Epoch: 132/300 cost: 0.600798425
#  Training accuracy: 0.800
#  Test accuracy: 0.580
# Epoch: 135/300 cost: 0.588666754
#  Training accuracy: 0.600
#  Test accuracy: 0.565
# Epoch: 138/300 cost: 0.567473711
#  Training accuracy: 0.700
#  Test accuracy: 0.594
# Epoch: 141/300 cost: 0.569411205
#  Training accuracy: 0.800
#  Test accuracy: 0.609
# Epoch: 144/300 cost: 0.486805230
#  Training accuracy: 0.900
#  Test accuracy: 0.609
# Epoch: 147/300 cost: 0.648439485
#  Training accuracy: 0.500
#  Test accuracy: 0.565
# Epoch: 150/300 cost: 0.613530466
#  Training accuracy: 0.600
#  Test accuracy: 0.609
# Epoch: 153/300 cost: 0.586685831
#  Training accuracy: 0.800
#  Test accuracy: 0.565
# Epoch: 156/300 cost: 0.590509310
#  Training accuracy: 0.900
#  Test accuracy: 0.594
# Epoch: 159/300 cost: 0.594662432
#  Training accuracy: 0.900
#  Test accuracy: 0.623
# Epoch: 162/300 cost: 0.568205304
#  Training accuracy: 0.600
#  Test accuracy: 0.609
# Epoch: 165/300 cost: 0.528122255
#  Training accuracy: 0.800
#  Test accuracy: 0.580
# Epoch: 168/300 cost: 0.600944992
#  Training accuracy: 0.700
#  Test accuracy: 0.580
# Epoch: 171/300 cost: 0.418435680
#  Training accuracy: 0.700
#  Test accuracy: 0.623
# Epoch: 174/300 cost: 0.548256190
#  Training accuracy: 0.600
#  Test accuracy: 0.594
# Epoch: 177/300 cost: 0.491546729
#  Training accuracy: 1.000
#  Test accuracy: 0.623
# Epoch: 180/300 cost: 0.590605807
#  Training accuracy: 0.700
#  Test accuracy: 0.580
# Epoch: 183/300 cost: 0.545167403
#  Training accuracy: 0.600
#  Test accuracy: 0.623
# Epoch: 186/300 cost: 0.496899520
#  Training accuracy: 0.800
#  Test accuracy: 0.623
# Epoch: 189/300 cost: 0.493101977
#  Training accuracy: 0.800
#  Test accuracy: 0.580
# Epoch: 192/300 cost: 0.495202857
#  Training accuracy: 0.800
#  Test accuracy: 0.609
# Epoch: 195/300 cost: 0.541655567
#  Training accuracy: 0.700
#  Test accuracy: 0.594
# Epoch: 198/300 cost: 0.517849513
#  Training accuracy: 0.500
#  Test accuracy: 0.681
# Epoch: 201/300 cost: 0.372657982
#  Training accuracy: 0.700
#  Test accuracy: 0.623
# Epoch: 204/300 cost: 0.533448183
#  Training accuracy: 0.600
#  Test accuracy: 0.594
# Epoch: 207/300 cost: 0.334943208
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 210/300 cost: 0.523527483
#  Training accuracy: 0.700
#  Test accuracy: 0.652
# Epoch: 213/300 cost: 0.435228196
#  Training accuracy: 0.700
#  Test accuracy: 0.609
# Epoch: 216/300 cost: 0.399540701
#  Training accuracy: 0.900
#  Test accuracy: 0.594
# Epoch: 219/300 cost: 0.409861467
#  Training accuracy: 0.800
#  Test accuracy: 0.609
# Epoch: 222/300 cost: 0.530741127
#  Training accuracy: 0.700
#  Test accuracy: 0.638
# Epoch: 225/300 cost: 0.523909621
#  Training accuracy: 0.800
#  Test accuracy: 0.638
# Epoch: 228/300 cost: 0.373088302
#  Training accuracy: 0.800
#  Test accuracy: 0.623
# Epoch: 231/300 cost: 0.387074877
#  Training accuracy: 0.900
#  Test accuracy: 0.623
# Epoch: 234/300 cost: 0.503911976
#  Training accuracy: 0.900
#  Test accuracy: 0.609
# Epoch: 237/300 cost: 0.524408245
#  Training accuracy: 0.800
#  Test accuracy: 0.623
# Epoch: 240/300 cost: 0.464397982
#  Training accuracy: 0.800
#  Test accuracy: 0.565
# Epoch: 243/300 cost: 0.538651504
#  Training accuracy: 0.700
#  Test accuracy: 0.565
# Epoch: 246/300 cost: 0.349060079
#  Training accuracy: 0.900
#  Test accuracy: 0.623
# Epoch: 249/300 cost: 0.379878552
#  Training accuracy: 1.000
#  Test accuracy: 0.594
# Epoch: 252/300 cost: 0.442446841
#  Training accuracy: 0.800
#  Test accuracy: 0.623
# Epoch: 255/300 cost: 0.397213951
#  Training accuracy: 0.500
#  Test accuracy: 0.638
# Epoch: 258/300 cost: 0.498339872
#  Training accuracy: 0.700
#  Test accuracy: 0.580
# Epoch: 261/300 cost: 0.335198759
#  Training accuracy: 1.000
#  Test accuracy: 0.580
# Epoch: 264/300 cost: 0.349017599
#  Training accuracy: 1.000
#  Test accuracy: 0.580
# Epoch: 267/300 cost: 0.340772879
#  Training accuracy: 0.900
#  Test accuracy: 0.580
# Epoch: 270/300 cost: 0.354040952
#  Training accuracy: 0.900
#  Test accuracy: 0.565
# Epoch: 273/300 cost: 0.350211734
#  Training accuracy: 0.800
#  Test accuracy: 0.594
# Epoch: 276/300 cost: 0.398840570
#  Training accuracy: 0.900
#  Test accuracy: 0.623
# Epoch: 279/300 cost: 0.384929654
#  Training accuracy: 0.900
#  Test accuracy: 0.594
# Epoch: 282/300 cost: 0.406212441
#  Training accuracy: 1.000
#  Test accuracy: 0.609
# Epoch: 285/300 cost: 0.361402836
#  Training accuracy: 0.700
#  Test accuracy: 0.623
# Epoch: 288/300 cost: 0.336335031
#  Training accuracy: 1.000
#  Test accuracy: 0.565
# Epoch: 291/300 cost: 0.310645048
#  Training accuracy: 1.000
#  Test accuracy: 0.551
# Epoch: 294/300 cost: 0.272800472
#  Training accuracy: 0.900
#  Test accuracy: 0.609
# Epoch: 297/300 cost: 0.353441984
#  Training accuracy: 0.800
#  Test accuracy: 0.565
# Optimization Finished!

# %%
#Let's plot training and testing acurracy across 300 epochs
print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]
# Out:
# 100

# %%
#Let's plot training and testing acurracy across 300 epochs
#print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, testing, label="Test Set Accuracy")
ax1.plot(x,training, label="Training Set Accuracy")
ax1.set_ylim([0.,1.])
ax1.set_xlabel("epoch")
ax1.set_ylabel("accuracy")
ax1.set_title("Transfer Learning - 18+ Males - Max Projection by Axis")

handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

fig.suptitle("Batch: %d, lr: %f, derivative: alff" % (batch_size, learning_rate) )
