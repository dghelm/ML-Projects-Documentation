# %%
# # CNN FINETUNING WITH PRE-TRAINED VGG NET - Small Training Size
# %matplotlib inline
import os
import numpy as np
import tensorflow as tf
import load_fmri_alff_dottest_transferlearning_axis as input_data
import matplotlib.pyplot as plt
import scipy.misc
import scipy.io
#from tensorflow.examples.tutorials.mnist import input_data

# Load Data
fmri = input_data.read_data_sets("../data/AllSubjects4cat.hdf5", fraction=1, channels=1)
trainimg   = fmri.train.images
trainlabel = fmri.train.labels
testimg    = fmri.test.images
testlabel  = fmri.test.labels
ntrain      = trainimg.shape[0]
ntest       = testimg.shape[0]
dim         = trainimg.shape[1]
nout        = trainlabel.shape[1]

print ("%d train images loaded" % (ntrain))
print ("%d test images loaded" % (ntest))
print ("%d dimensional input" % (dim))
# print ("%d classes" % (nclass))
print ("shape of 'trainimg' is %s" % (trainimg.shape,))
print ("shape of 'testimg' is %s" % (testimg.shape,))

print (trainlabel.shape)
# Out:
# Loading Training Imagery...
# .....................
# Loading Test Imagery...
# .......204 train images loaded
# 69 test images loaded
# 10800 dimensional input
# shape of 'trainimg' is (204, 10800)
# shape of 'testimg' is (69, 10800)
# (204, 2)

# %%
img = np.reshape(testimg[9],(60,60,3) )
np.max(img[:,:,0])
# Out:
# 1.0

# %%
img = np.reshape(testimg[27],(60,60,3) )
plt.imshow(img[:,:,:])
plt.axis("off")
# Out:
# (-0.5, 59.5, 59.5, -0.5)

# %%
trainimg_tensor = np.ndarray((ntrain, 60, 60, 3))
for i in range(ntrain):
    currimg = trainimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    trainimg_tensor[i, :, :, :] = currimg
print ("shape of trainimg_tensor is %s" % (trainimg_tensor.shape,))

testimg_tensor = np.ndarray((ntest, 60, 60, 3))
for i in range(ntest):
    currimg = testimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    testimg_tensor[i, :, :, :] = currimg
print ("shape of testimg_tensor is %s" % (testimg_tensor.shape,))
# Out:
# shape of trainimg_tensor is (204, 60, 60, 3)
# shape of testimg_tensor is (69, 60, 60, 3)

# %%
# # DEFINE A FUNCTION FOR USING PRETRAINED VGG NETWORK

def net(data_path, input_image):
    layers = (
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1',
        'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3',
        'relu3_3', 'conv3_4', 'relu3_4', 'pool3',
        'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'conv4_3',
        'relu4_3', 'conv4_4', 'relu4_4', 'pool4',
        'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'conv5_3',
        'relu5_3', 'conv5_4', 'relu5_4'
    )
    data = scipy.io.loadmat(data_path)
    mean = data['normalization'][0][0][0]
    mean_pixel = np.mean(mean, axis=(0, 1))
    weights = data['layers'][0]
    net = {}
    current = input_image
    for i, name in enumerate(layers):
        kind = name[:4]
        if kind == 'conv':
            kernels, bias = weights[i][0][0][0][0]
            # matconvnet: weights are [width, height, in_channels, out_channels]
            # tensorflow: weights are [height, width, in_channels, out_channels]
            kernels = np.transpose(kernels, (1, 0, 2, 3))
            bias = bias.reshape(-1)
            current = _conv_layer(current, kernels, bias)
        elif kind == 'relu':
            current = tf.nn.relu(current)
        elif kind == 'pool':
            current = _pool_layer(current)
        net[name] = current

    assert len(net) == len(layers)
    return net, mean_pixel
with tf.device("/cpu:0"):
    def _conv_layer(input, weights, bias):
        conv = tf.nn.conv2d(input, tf.constant(weights), strides=(1, 1, 1, 1),
                            padding='SAME')
        return tf.nn.bias_add(conv, bias)

    def _pool_layer(input):
        return tf.nn.max_pool(input, ksize=(1, 2, 2, 1), strides=(1, 2, 2, 1),
                              padding='SAME')

    def preprocess(image, mean_pixel):
        return image - mean_pixel

    def unprocess(image, mean_pixel):
        return image + mean_pixel

# %%
## EXTRACT FEATURES FROM THE VGG NETWORK
cwd = os.getcwd()
VGG_PATH = cwd + "/data/imagenet-vgg-verydeep-19.mat"
with tf.Graph().as_default(), tf.Session() as sess:
    with tf.device("/cpu:0"):
        img_placeholder = tf.placeholder(tf.float32, shape=(None, 60, 60, 3))
        net_val, mean_pixel = net(VGG_PATH, img_placeholder)
        train_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: trainimg_tensor})
        print("Train Features finished...")
        test_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: testimg_tensor})
print ("TYPE OF 'train_features' IS %s" % (type(train_features)))
print ("SHAPE OF 'train_features' IS %s" % (train_features.shape,))
print ("TYPE OF 'test_features' IS %s" % (type(test_features)))
print ("SHAPE OF 'test_features' IS %s" % (test_features.shape,))
print("PREPROCESSING DONE")
# Out:
# Train Features finished...
# TYPE OF 'train_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'train_features' IS (204, 4, 4, 512)
# TYPE OF 'test_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'test_features' IS (69, 4, 4, 512)
# PREPROCESSING DONE

# %%
# # VECTORIZE CNN FEATURES

train_vectorized = np.ndarray((ntrain, 8192))
test_vectorized = np.ndarray((ntest, 8192))
for i in range(ntrain):
    curr_feat = train_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    train_vectorized[i, :] = curr_feat_vec

for i in range(ntest):
    curr_feat = test_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    test_vectorized[i, :] = curr_feat_vec

print ("SHAPE OF 'train_vectorized' IS %s" % (train_vectorized.shape,))
print ("SHAPE OF 'test_vectorized' IS %s" % (test_vectorized.shape,))

# # DEFINE NETWORKS AND FUNCTIONS (ADD 2LAYER MLP)
# Out:
# SHAPE OF 'train_vectorized' IS (204, 8192)
# SHAPE OF 'test_vectorized' IS (69, 8192)

# %%
# Parameters
learning_rate = 0.0001  # default 0.0001
training_epochs = 400
batch_size = 102  # default 100
display_step = 2

# %%
# Network
with tf.device("/cpu:0"):
    n_input = dim
    n_output = 2
    # n_output = nclass
    weights = {
        'wd1': tf.Variable(tf.random_normal([8192, 1024], stddev=0.1)),
        'wd2': tf.Variable(tf.random_normal([1024, n_output], stddev=0.1))
    }
    biases = {
        'bd1': tf.Variable(tf.random_normal([1024], stddev=0.1)),
        'bd2': tf.Variable(tf.random_normal([n_output], stddev=0.1))
    }


    def conv_basic(_input, _w, _b, _keepratio):
        # Input
        _input_r = _input
        # Vectorize
        _dense1 = tf.reshape(_input_r, [-1, _w['wd1'].get_shape().as_list()[0]])
        # Fc1
        _fc1 = tf.nn.relu(tf.add(tf.matmul(_dense1, _w['wd1']), _b['bd1']))
        _fc_dr1 = tf.nn.dropout(_fc1, _keepratio)
        # Fc2
        _out = tf.add(tf.matmul(_fc_dr1, _w['wd2']), _b['bd2'])
        # Return everything
        out = {'input_r': _input_r, 'dense1': _dense1,
               'fc1': _fc1, 'fc_dr1': _fc_dr1, 'out': _out}
        return out

# tf Graph input
x = tf.placeholder(tf.float32, [None, 8192])
y = tf.placeholder(tf.float32, [None, n_output])
keepratio = tf.placeholder(tf.float32)

# %%
# Functions!
with tf.device("/cpu:0"):
    _pred = conv_basic(x, weights, biases, keepratio)['out']
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(_pred, y))
    optm = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    _corr = tf.equal(tf.argmax(_pred, 1), tf.argmax(y, 1))  # Count corrects
    accr = tf.reduce_mean(tf.cast(_corr, tf.float32))  # Accuracy
    init = tf.initialize_all_variables()

print ("Network Ready to Go!")
# Out:
# Network Ready to Go!

# %%
testing = []
training = []

with tf.device("/cpu:0"):
    sess = tf.Session()
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        num_batch = int(ntrain / batch_size) + 1
        # Loop over all batches
        for i in range(num_batch):
            randidx = np.random.randint(ntrain, size=batch_size)
            batch_xs = train_vectorized[randidx, :]
            batch_ys = trainlabel[randidx, :]
            # Fit training using batch data
            sess.run(optm, feed_dict={x: batch_xs, y: batch_ys, keepratio: 0.7})
            # Compute average loss
            avg_cost += sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.}) / num_batch

        # Display logs per epoch step
        if epoch % display_step == 0:
            print ("Epoch: %03d/%03d cost: %.9f" % (epoch, training_epochs, avg_cost))
            train_acc = sess.run(accr, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.})
            print (" Training accuracy: %.3f" % (train_acc))
            training.append(train_acc)
            test_acc = sess.run(accr, feed_dict={x: test_vectorized, y: testlabel, keepratio: 1.})
            print (" Test accuracy: %.3f" % (test_acc))
            testing.append(test_acc)

print ("Optimization Finished!")
# Out:
# Epoch: 000/400 cost: 0.974758486
#  Training accuracy: 0.618
#  Test accuracy: 0.406
# Epoch: 002/400 cost: 1.025465786
#  Training accuracy: 0.706
#  Test accuracy: 0.536
# Epoch: 004/400 cost: 0.930215438
#  Training accuracy: 0.794
#  Test accuracy: 0.507
# Epoch: 006/400 cost: 0.854415894
#  Training accuracy: 0.667
#  Test accuracy: 0.464
# Epoch: 008/400 cost: 0.914438168
#  Training accuracy: 0.647
#  Test accuracy: 0.478
# Epoch: 010/400 cost: 0.787032803
#  Training accuracy: 0.647
#  Test accuracy: 0.420
# Epoch: 012/400 cost: 1.121866564
#  Training accuracy: 0.608
#  Test accuracy: 0.507
# Epoch: 014/400 cost: 0.751319806
#  Training accuracy: 0.686
#  Test accuracy: 0.406
# Epoch: 016/400 cost: 0.893088241
#  Training accuracy: 0.686
#  Test accuracy: 0.493
# Epoch: 018/400 cost: 0.742670596
#  Training accuracy: 0.647
#  Test accuracy: 0.435
# Epoch: 020/400 cost: 0.934629877
#  Training accuracy: 0.667
#  Test accuracy: 0.522
# Epoch: 022/400 cost: 0.855524023
#  Training accuracy: 0.686
#  Test accuracy: 0.406
# Epoch: 024/400 cost: 0.817041179
#  Training accuracy: 0.676
#  Test accuracy: 0.493
# Epoch: 026/400 cost: 0.694145282
#  Training accuracy: 0.696
#  Test accuracy: 0.493
# Epoch: 028/400 cost: 0.671820343
#  Training accuracy: 0.814
#  Test accuracy: 0.478
# Epoch: 090/400 cost: 0.288268963
#  Training accuracy: 0.892
#  Test accuracy: 0.507
# Epoch: 092/400 cost: 0.344764362
#  Training accuracy: 0.853
#  Test accuracy: 0.464
# Epoch: 094/400 cost: 0.326577783
#  Training accuracy: 0.853
#  Test accuracy: 0.493
# Epoch: 096/400 cost: 0.259533018
#  Training accuracy: 0.902
#  Test accuracy: 0.478
# Epoch: 098/400 cost: 0.324451725
#  Training accuracy: 0.824
#  Test accuracy: 0.478
# Epoch: 100/400 cost: 0.286570887
#  Training accuracy: 0.873
#  Test accuracy: 0.435
# Epoch: 102/400 cost: 0.433932076
#  Training accuracy: 0.853
#  Test accuracy: 0.507
# Epoch: 104/400 cost: 0.247389406
#  Training accuracy: 0.931
#  Test accuracy: 0.507
# Epoch: 106/400 cost: 0.220847492
#  Training accuracy: 0.941
#  Test accuracy: 0.493
# Epoch: 108/400 cost: 0.246055409
#  Training accuracy: 0.882
#  Test accuracy: 0.493
# Epoch: 110/400 cost: 0.199573422
#  Training accuracy: 0.961
#  Test accuracy: 0.464
# Epoch: 112/400 cost: 0.244769499
#  Training accuracy: 0.931
#  Test accuracy: 0.507
# Epoch: 114/400 cost: 0.241679937
#  Training accuracy: 0.902
#  Test accuracy: 0.522
# Epoch: 116/400 cost: 0.213014454
#  Training accuracy: 0.922
#  Test accuracy: 0.522
# Epoch: 118/400 cost: 0.176331967
#  Training accuracy: 0.951
#  Test accuracy: 0.522
# Epoch: 120/400 cost: 0.214579031
#  Training accuracy: 0.922
#  Test accuracy: 0.493
# Epoch: 122/400 cost: 0.162837098
#  Training accuracy: 0.961
#  Test accuracy: 0.493
# Epoch: 124/400 cost: 0.171007593
#  Training accuracy: 0.961
#  Test accuracy: 0.507
# Epoch: 126/400 cost: 0.221291299
#  Training accuracy: 0.931
#  Test accuracy: 0.493
# Epoch: 128/400 cost: 0.153765631
#  Training accuracy: 0.971
#  Test accuracy: 0.507
# Epoch: 130/400 cost: 0.209617436
#  Training accuracy: 0.912
#  Test accuracy: 0.522
# Epoch: 132/400 cost: 0.217488885
#  Training accuracy: 0.951
#  Test accuracy: 0.507
# Epoch: 134/400 cost: 0.176232174
#  Training accuracy: 0.961
#  Test accuracy: 0.507
# Epoch: 136/400 cost: 0.174650942
#  Training accuracy: 0.912
#  Test accuracy: 0.522
# Epoch: 138/400 cost: 0.162775507
#  Training accuracy: 0.882
#  Test accuracy: 0.507
# Epoch: 140/400 cost: 0.148584440
#  Training accuracy: 0.971
#  Test accuracy: 0.522
# Epoch: 142/400 cost: 0.130001421
#  Training accuracy: 0.961
#  Test accuracy: 0.507
# Epoch: 144/400 cost: 0.142529257
#  Training accuracy: 0.931
#  Test accuracy: 0.507
# Epoch: 146/400 cost: 0.116885014
#  Training accuracy: 0.980
#  Test accuracy: 0.522
# Epoch: 148/400 cost: 0.152634958
#  Training accuracy: 0.912
#  Test accuracy: 0.522
# Epoch: 150/400 cost: 0.167465096
#  Training accuracy: 0.941
#  Test accuracy: 0.522
# Epoch: 152/400 cost: 0.137112324
#  Training accuracy: 0.951
#  Test accuracy: 0.493
# Epoch: 154/400 cost: 0.172428971
#  Training accuracy: 0.931
#  Test accuracy: 0.493
# Epoch: 156/400 cost: 0.141213949
#  Training accuracy: 0.971
#  Test accuracy: 0.507
# Epoch: 158/400 cost: 0.125978378
#  Training accuracy: 0.971
#  Test accuracy: 0.507
# Epoch: 160/400 cost: 0.116151201
#  Training accuracy: 0.941
#  Test accuracy: 0.507
# Epoch: 162/400 cost: 0.115511678
#  Training accuracy: 0.971
#  Test accuracy: 0.522
# Epoch: 164/400 cost: 0.136884019
#  Training accuracy: 0.941
#  Test accuracy: 0.493
# Epoch: 166/400 cost: 0.137542913
#  Training accuracy: 0.961
#  Test accuracy: 0.478
# Epoch: 168/400 cost: 0.146482488
#  Training accuracy: 0.951
#  Test accuracy: 0.493
# Epoch: 170/400 cost: 0.159667626
#  Training accuracy: 0.941
#  Test accuracy: 0.478
# Epoch: 172/400 cost: 0.168270464
#  Training accuracy: 0.912
#  Test accuracy: 0.493
# Epoch: 174/400 cost: 0.135195874
#  Training accuracy: 0.971
#  Test accuracy: 0.493
# Epoch: 176/400 cost: 0.142525246
#  Training accuracy: 0.971
#  Test accuracy: 0.493
# Epoch: 178/400 cost: 0.103007220
#  Training accuracy: 0.951
#  Test accuracy: 0.507
# Epoch: 180/400 cost: 0.136251502
#  Training accuracy: 0.971
#  Test accuracy: 0.493
# Epoch: 182/400 cost: 0.116971525
#  Training accuracy: 0.941
#  Test accuracy: 0.536
# Epoch: 184/400 cost: 0.108104100
#  Training accuracy: 0.980
#  Test accuracy: 0.493
# Epoch: 186/400 cost: 0.134296512
#  Training accuracy: 0.961
#  Test accuracy: 0.507
# Epoch: 188/400 cost: 0.114889880
#  Training accuracy: 0.990
#  Test accuracy: 0.478
# Epoch: 190/400 cost: 0.090302763
#  Training accuracy: 0.971
#  Test accuracy: 0.493
# Epoch: 192/400 cost: 0.077426277
#  Training accuracy: 0.990
#  Test accuracy: 0.493
# Epoch: 194/400 cost: 0.108179492
#  Training accuracy: 0.980
#  Test accuracy: 0.478
# Epoch: 196/400 cost: 0.104000911
#  Training accuracy: 0.980
#  Test accuracy: 0.493
# Epoch: 198/400 cost: 0.073901976
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 200/400 cost: 0.099948185
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 202/400 cost: 0.077731814
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 204/400 cost: 0.090139565
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 206/400 cost: 0.081625792
#  Training accuracy: 1.000
#  Test accuracy: 0.478
# Epoch: 208/400 cost: 0.089813131
#  Training accuracy: 0.971
#  Test accuracy: 0.522
# Epoch: 210/400 cost: 0.081139259
#  Training accuracy: 0.980
#  Test accuracy: 0.493
# Epoch: 212/400 cost: 0.088432702
#  Training accuracy: 0.990
#  Test accuracy: 0.493
# Epoch: 214/400 cost: 0.114905539
#  Training accuracy: 0.961
#  Test accuracy: 0.507
# Epoch: 216/400 cost: 0.082010455
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch:
#  Training accuracy: 1.000
#  Test accuracy: 0.522
# Epoch: 340/400 cost: 0.032463105
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 342/400 cost: 0.038168875
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 344/400 cost: 0.040881065
#  Training accuracy: 1.000
#  Test accuracy: 0.478
# Epoch: 346/400 cost: 0.041810696
#  Training accuracy: 1.000
#  Test accuracy: 0.536
# Epoch: 348/400 cost: 0.043232220
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 350/400 cost: 0.038207576
#  Training accuracy: 1.000
#  Test accuracy: 0.536
# Epoch: 352/400 cost: 0.040190494
#  Training accuracy: 1.000
#  Test accuracy: 0.478
# Epoch: 354/400 cost: 0.040510103
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 356/400 cost: 0.032990864
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 358/400 cost: 0.036770417
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 360/400 cost: 0.035361867
#  Training accuracy: 1.000
#  Test accuracy: 0.522
# Epoch: 362/400 cost: 0.040009900
#  Training accuracy: 1.000
#  Test accuracy: 0.464
# Epoch: 364/400 cost: 0.037664400
#  Training accuracy: 1.000
#  Test accuracy: 0.536
# Epoch: 366/400 cost: 0.043703267
#  Training accuracy: 0.990
#  Test accuracy: 0.507
# Epoch: 368/400 cost: 0.039286156
#  Training accuracy: 1.000
#  Test accuracy: 0.551
# Epoch: 370/400 cost: 0.045068730
#  Training accuracy: 0.980
#  Test accuracy: 0.493
# Epoch: 372/400 cost: 0.035688239
#  Training accuracy: 1.000
#  Test accuracy: 0.536
# Epoch: 374/400 cost: 0.031846888
#  Training accuracy: 1.000
#  Test accuracy: 0.478
# Epoch: 376/400 cost: 0.031459516
#  Training accuracy: 1.000
#  Test accuracy: 0.522
# Epoch: 378/400 cost: 0.030625496
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 380/400 cost: 0.035998551
#  Training accuracy: 1.000
#  Test accuracy: 0.536
# Epoch: 382/400 cost: 0.033987269
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 384/400 cost: 0.036142427
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 386/400 cost: 0.032287247
#  Training accuracy: 1.000
#  Test accuracy: 0.478
# Epoch: 388/400 cost: 0.026141456
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 390/400 cost: 0.026387898
#  Training accuracy: 1.000
#  Test accuracy: 0.507
# Epoch: 392/400 cost: 0.034183914
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Epoch: 394/400 cost: 0.029616758
#  Training accuracy: 1.000
#  Test accuracy: 0.464
# Epoch: 396/400 cost: 0.026519461
#  Training accuracy: 1.000
#  Test accuracy: 0.522
# Epoch: 398/400 cost: 0.030859683
#  Training accuracy: 1.000
#  Test accuracy: 0.493
# Optimization Finished!

# %%
#Let's plot training and testing acurracy across 300 epochs
print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]
# Out:
# 29

# %%
#Let's plot training and testing acurracy across 300 epochs
#print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, testing, label="Test Set Accuracy")
ax1.plot(x,training, label="Training Set Accuracy")
ax1.set_ylim([0.,1.])
ax1.set_xlabel("epoch")
ax1.set_ylabel("accuracy")
ax1.set_title("Transfer Learning - 18+ Male - Max Projection by Axis")

handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

fig.suptitle("Batch: %d, lr: %f, derivative: alff" % (batch_size, learning_rate) )

# %%
#Let's plot training and testing acurracy across 300 epochs
#print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, testing, label="Test Set Accuracy")
ax1.plot(x,training, label="Training Set Accuracy")
ax1.set_ylim([0.,1.])
ax1.set_xlabel("epoch")
ax1.set_ylabel("accuracy")
ax1.set_title("Transfer Learning - All Subjects - Dot Test - Max Projection by Axis")

handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

fig.suptitle("Batch: %d, lr: %f, derivative: alff" % (batch_size, learning_rate) )
