# %%
# # CNN FINETUNING WITH PRE-TRAINED VGG NET - Small Training Size
# %matplotlib inline
import os
import numpy as np
import tensorflow as tf
import load_fmri_alff_dottest_transferlearning_axis_adol as input_data
import matplotlib.pyplot as plt
import scipy.misc
import scipy.io
#from tensorflow.examples.tutorials.mnist import input_data

# Load Data
fmri = input_data.read_data_sets("../data/AllSubjects4cat.hdf5", fraction=1, channels=1)
trainimg   = fmri.train.images
trainlabel = fmri.train.labels
testimg    = fmri.test.images
testlabel  = fmri.test.labels
ntrain      = trainimg.shape[0]
ntest       = testimg.shape[0]
dim         = trainimg.shape[1]
nout        = trainlabel.shape[1]

print ("%d train images loaded" % (ntrain))
print ("%d test images loaded" % (ntest))
print ("%d dimensional input" % (dim))
# print ("%d classes" % (nclass))
print ("shape of 'trainimg' is %s" % (trainimg.shape,))
print ("shape of 'testimg' is %s" % (testimg.shape,))

print (trainlabel.shape)
# Out:
# Loading Training Imagery...
# .............................................
# Loading Test Imagery...
# ...............448 train images loaded
# 150 test images loaded
# 10800 dimensional input
# shape of 'trainimg' is (448, 10800)
# shape of 'testimg' is (150, 10800)
# (448, 2)

# %%
img = np.reshape(testimg[9],(60,60,3) )
np.max(img[:,:,0])
# Out:
# 1.0

# %%
img = np.reshape(testimg[27],(60,60,3) )
plt.imshow(img[:,:,:])
plt.axis("off")
# Out:
# (-0.5, 59.5, 59.5, -0.5)

# %%
trainimg_tensor = np.ndarray((ntrain, 60, 60, 3))
for i in range(ntrain):
    currimg = trainimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    trainimg_tensor[i, :, :, :] = currimg
print ("shape of trainimg_tensor is %s" % (trainimg_tensor.shape,))

testimg_tensor = np.ndarray((ntest, 60, 60, 3))
for i in range(ntest):
    currimg = testimg[i, :]
    currimg = np.reshape(currimg, [60, 60, 3])
    testimg_tensor[i, :, :, :] = currimg
print ("shape of testimg_tensor is %s" % (testimg_tensor.shape,))
# Out:
# shape of trainimg_tensor is (448, 60, 60, 3)
# shape of testimg_tensor is (150, 60, 60, 3)

# %%
# # DEFINE A FUNCTION FOR USING PRETRAINED VGG NETWORK

def net(data_path, input_image):
    layers = (
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1',
        'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3',
        'relu3_3', 'conv3_4', 'relu3_4', 'pool3',
        'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'conv4_3',
        'relu4_3', 'conv4_4', 'relu4_4', 'pool4',
        'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'conv5_3',
        'relu5_3', 'conv5_4', 'relu5_4'
    )
    data = scipy.io.loadmat(data_path)
    mean = data['normalization'][0][0][0]
    mean_pixel = np.mean(mean, axis=(0, 1))
    weights = data['layers'][0]
    net = {}
    current = input_image
    for i, name in enumerate(layers):
        kind = name[:4]
        if kind == 'conv':
            kernels, bias = weights[i][0][0][0][0]
            # matconvnet: weights are [width, height, in_channels, out_channels]
            # tensorflow: weights are [height, width, in_channels, out_channels]
            kernels = np.transpose(kernels, (1, 0, 2, 3))
            bias = bias.reshape(-1)
            current = _conv_layer(current, kernels, bias)
        elif kind == 'relu':
            current = tf.nn.relu(current)
        elif kind == 'pool':
            current = _pool_layer(current)
        net[name] = current

    assert len(net) == len(layers)
    return net, mean_pixel
with tf.device("/cpu:0"):
    def _conv_layer(input, weights, bias):
        conv = tf.nn.conv2d(input, tf.constant(weights), strides=(1, 1, 1, 1),
                            padding='SAME')
        return tf.nn.bias_add(conv, bias)

    def _pool_layer(input):
        return tf.nn.max_pool(input, ksize=(1, 2, 2, 1), strides=(1, 2, 2, 1),
                              padding='SAME')

    def preprocess(image, mean_pixel):
        return image - mean_pixel

    def unprocess(image, mean_pixel):
        return image + mean_pixel

# %%
## EXTRACT FEATURES FROM THE VGG NETWORK
cwd = os.getcwd()
VGG_PATH = cwd + "/data/imagenet-vgg-verydeep-19.mat"
with tf.Graph().as_default(), tf.Session() as sess:
    with tf.device("/cpu:0"):
        img_placeholder = tf.placeholder(tf.float32, shape=(None, 60, 60, 3))
        net_val, mean_pixel = net(VGG_PATH, img_placeholder)
        train_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: trainimg_tensor})
        print("Train Features finished...")
        test_features = net_val['relu5_4'].eval(feed_dict={img_placeholder: testimg_tensor})
print ("TYPE OF 'train_features' IS %s" % (type(train_features)))
print ("SHAPE OF 'train_features' IS %s" % (train_features.shape,))
print ("TYPE OF 'test_features' IS %s" % (type(test_features)))
print ("SHAPE OF 'test_features' IS %s" % (test_features.shape,))
print("PREPROCESSING DONE")
# Out:
# Train Features finished...
# TYPE OF 'train_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'train_features' IS (448, 4, 4, 512)
# TYPE OF 'test_features' IS <type 'numpy.ndarray'>
# SHAPE OF 'test_features' IS (150, 4, 4, 512)
# PREPROCESSING DONE

# %%
# # VECTORIZE CNN FEATURES

train_vectorized = np.ndarray((ntrain, 8192))
test_vectorized = np.ndarray((ntest, 8192))
for i in range(ntrain):
    curr_feat = train_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    train_vectorized[i, :] = curr_feat_vec

for i in range(ntest):
    curr_feat = test_features[i, :, :, :]
    curr_feat_vec = np.reshape(curr_feat, (1, -1))
    test_vectorized[i, :] = curr_feat_vec

print ("SHAPE OF 'train_vectorized' IS %s" % (train_vectorized.shape,))
print ("SHAPE OF 'test_vectorized' IS %s" % (test_vectorized.shape,))

# # DEFINE NETWORKS AND FUNCTIONS (ADD 2LAYER MLP)
# Out:
# SHAPE OF 'train_vectorized' IS (448, 8192)
# SHAPE OF 'test_vectorized' IS (150, 8192)

# %%
# Parameters
learning_rate = 0.00001  # default 0.0001
training_epochs = 300
batch_size = 10  # default 100
display_step = 3

# %%
# Network
with tf.device("/cpu:0"):
    n_input = dim
    n_output = 2
    # n_output = nclass
    weights = {
        'wd1': tf.Variable(tf.random_normal([8192, 1024], stddev=0.1)),
        'wd2': tf.Variable(tf.random_normal([1024, n_output], stddev=0.1))
    }
    biases = {
        'bd1': tf.Variable(tf.random_normal([1024], stddev=0.1)),
        'bd2': tf.Variable(tf.random_normal([n_output], stddev=0.1))
    }


    def conv_basic(_input, _w, _b, _keepratio):
        # Input
        _input_r = _input
        # Vectorize
        _dense1 = tf.reshape(_input_r, [-1, _w['wd1'].get_shape().as_list()[0]])
        # Fc1
        _fc1 = tf.nn.relu(tf.add(tf.matmul(_dense1, _w['wd1']), _b['bd1']))
        _fc_dr1 = tf.nn.dropout(_fc1, _keepratio)
        # Fc2
        _out = tf.add(tf.matmul(_fc_dr1, _w['wd2']), _b['bd2'])
        # Return everything
        out = {'input_r': _input_r, 'dense1': _dense1,
               'fc1': _fc1, 'fc_dr1': _fc_dr1, 'out': _out}
        return out

# tf Graph input
x = tf.placeholder(tf.float32, [None, 8192])
y = tf.placeholder(tf.float32, [None, n_output])
keepratio = tf.placeholder(tf.float32)

# %%
# Functions!
with tf.device("/cpu:0"):
    _pred = conv_basic(x, weights, biases, keepratio)['out']
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(_pred, y))
    optm = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    _corr = tf.equal(tf.argmax(_pred, 1), tf.argmax(y, 1))  # Count corrects
    accr = tf.reduce_mean(tf.cast(_corr, tf.float32))  # Accuracy
    init = tf.initialize_all_variables()

print ("Network Ready to Go!")
# Out:
# Network Ready to Go!

# %%
testing = []
training = []

with tf.device("/cpu:0"):
    sess = tf.Session()
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        num_batch = int(ntrain / batch_size) + 1
        # Loop over all batches
        for i in range(num_batch):
            randidx = np.random.randint(ntrain, size=batch_size)
            batch_xs = train_vectorized[randidx, :]
            batch_ys = trainlabel[randidx, :]
            # Fit training using batch data
            sess.run(optm, feed_dict={x: batch_xs, y: batch_ys, keepratio: 0.7})
            # Compute average loss
            avg_cost += sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.}) / num_batch

        # Display logs per epoch step
        if epoch % display_step == 0:
            print ("Epoch: %03d/%03d cost: %.9f" % (epoch, training_epochs, avg_cost))
            train_acc = sess.run(accr, feed_dict={x: batch_xs, y: batch_ys, keepratio: 1.})
            print (" Training accuracy: %.3f" % (train_acc))
            training.append(train_acc)
            test_acc = sess.run(accr, feed_dict={x: test_vectorized, y: testlabel, keepratio: 1.})
            print (" Test accuracy: %.3f" % (test_acc))
            testing.append(test_acc)

print ("Optimization Finished!")
# Out:
# Epoch: 000/300 cost: 1.431111957
#  Training accuracy: 0.300
#  Test accuracy: 0.500
# Epoch: 003/300 cost: 0.955767330
#  Training accuracy: 0.500
#  Test accuracy: 0.513
# Epoch: 006/300 cost: 1.031513154
#  Training accuracy: 0.800
#  Test accuracy: 0.527
# Epoch: 009/300 cost: 0.807143319
#  Training accuracy: 0.600
#  Test accuracy: 0.553
# Epoch: 012/300 cost: 0.830227627
#  Training accuracy: 0.500
#  Test accuracy: 0.527
# Epoch: 015/300 cost: 0.870370909
#  Training accuracy: 0.500
#  Test accuracy: 0.553
# Epoch: 018/300 cost: 0.812117914
#  Training accuracy: 0.700
#  Test accuracy: 0.507
# Epoch: 021/300 cost: 0.808442399
#  Training accuracy: 0.400
#  Test accuracy: 0.487
# Epoch: 024/300 cost: 0.814633507
#  Training accuracy: 0.600
#  Test accuracy: 0.487
# Epoch: 027/300 cost: 0.794370633
#  Training accuracy: 0.500
#  Test accuracy: 0.507
# Epoch: 030/300 cost: 0.742709020
#  Training accuracy: 0.800
#  Test accuracy: 0.547
# Epoch: 033/300 cost: 0.826137511
#  Training accuracy: 0.200
#  Test accuracy: 0.540
# Epoch: 036/300 cost: 0.744010274
#  Training accuracy: 0.600
#  Test accuracy: 0.493
# Epoch: 039/300 cost: 0.835901260
#  Training accuracy: 0.400
#  Test accuracy: 0.547
# Epoch: 042/300 cost: 0.770699326
#  Training accuracy: 0.800
#  Test accuracy: 0.520
# Epoch: 045/300 cost: 0.627634815
#  Training accuracy: 0.800
#  Test accuracy: 0.500
# Epoch: 048/300 cost: 0.676561802
#  Training accuracy: 0.800
#  Test accuracy: 0.527
# Epoch: 051/300 cost: 0.815066246
#  Training accuracy: 0.600
#  Test accuracy: 0.520
# Epoch: 054/300 cost: 0.737377346
#  Training accuracy: 0.600
#  Test accuracy: 0.513
# Epoch: 057/300 cost: 0.746618713
#  Training accuracy: 0.500
#  Test accuracy: 0.440
# Epoch: 060/300 cost: 0.670796086
#  Training accuracy: 0.700
#  Test accuracy: 0.560
# Epoch: 063/300 cost: 0.698007509
#  Training accuracy: 0.800
#  Test accuracy: 0.473
# Epoch: 066/300 cost: 0.607829630
#  Training accuracy: 0.800
#  Test accuracy: 0.527
# Epoch: 069/300 cost: 0.639248851
#  Training accuracy: 0.800
#  Test accuracy: 0.553
# Epoch: 072/300 cost: 0.632556501
#  Training accuracy: 0.900
#  Test accuracy: 0.533
# Epoch: 075/300 cost: 0.615419775
#  Training accuracy: 0.500
#  Test accuracy: 0.493
# Epoch: 078/300 cost: 0.633297360
#  Training accuracy: 0.400
#  Test accuracy: 0.547
# Epoch: 081/300 cost: 0.665486253
#  Training accuracy: 0.700
#  Test accuracy: 0.553
# Epoch: 084/300 cost: 0.582540984
#  Training accuracy: 0.900
#  Test accuracy: 0.560
# Epoch: 087/300 cost: 0.630722846
#  Training accuracy: 0.700
#  Test accuracy: 0.567
# Epoch: 090/300 cost: 0.552472794
#  Training accuracy: 0.700
#  Test accuracy: 0.480
# Epoch: 093/300 cost: 0.590889536
#  Training accuracy: 0.900
#  Test accuracy: 0.540
# Epoch: 096/300 cost: 0.566033690
#  Training accuracy: 1.000
#  Test accuracy: 0.560
# Epoch: 099/300 cost: 0.530891821
#  Training accuracy: 0.800
#  Test accuracy: 0.520
# Epoch: 102/300 cost: 0.502070292
#  Training accuracy: 0.700
#  Test accuracy: 0.480
# Epoch: 105/300 cost: 0.525104562
#  Training accuracy: 1.000
#  Test accuracy: 0.540
# Epoch: 108/300 cost: 0.652749920
#  Training accuracy: 0.600
#  Test accuracy: 0.500
# Epoch: 111/300 cost: 0.481055055
#  Training accuracy: 0.600
#  Test accuracy: 0.553
# Epoch: 114/300 cost: 0.527367220
#  Training accuracy: 0.500
#  Test accuracy: 0.500
# Epoch: 117/300 cost: 0.537116571
#  Training accuracy: 0.900
#  Test accuracy: 0.480
# Epoch: 120/300 cost: 0.499832184
#  Training accuracy: 0.900
#  Test accuracy: 0.547
# Epoch: 123/300 cost: 0.566081406
#  Training accuracy: 0.800
#  Test accuracy: 0.507
# Epoch: 126/300 cost: 0.588967595
#  Training accuracy: 0.700
#  Test accuracy: 0.487
# Epoch: 129/300 cost: 0.468375570
#  Training accuracy: 0.700
#  Test accuracy: 0.527
# Epoch: 132/300 cost: 0.448046806
#  Training accuracy: 0.700
#  Test accuracy: 0.547
# Epoch: 135/300 cost: 0.468008741
#  Training accuracy: 0.700
#  Test accuracy: 0.533
# Epoch: 138/300 cost: 0.480103042
#  Training accuracy: 0.700
#  Test accuracy: 0.527
# Epoch: 141/300 cost: 0.480176515
#  Training accuracy: 0.700
#  Test accuracy: 0.520
# Epoch: 144/300 cost: 0.484124485
#  Training accuracy: 0.800
#  Test accuracy: 0.507
# Epoch: 147/300 cost: 0.415645129
#  Training accuracy: 0.900
#  Test accuracy: 0.507
# Epoch: 150/300 cost: 0.431317286
#  Training accuracy: 0.800
#  Test accuracy: 0.540
# Epoch: 153/300 cost: 0.400000055
#  Training accuracy: 0.800
#  Test accuracy: 0.520
# Epoch: 156/300 cost: 0.446889644
#  Training accuracy: 0.800
#  Test accuracy: 0.520
# Epoch: 159/300 cost: 0.422398155
#  Training accuracy: 0.900
#  Test accuracy: 0.500
# Epoch: 162/300 cost: 0.445119567
#  Training accuracy: 1.000
#  Test accuracy: 0.560
# Epoch: 165/300 cost: 0.482827304
#  Training accuracy: 0.700
#  Test accuracy: 0.520
# Epoch: 168/300 cost: 0.478205498
#  Training accuracy: 0.600
#  Test accuracy: 0.540
# Epoch: 171/300 cost: 0.374754261
#  Training accuracy: 0.900
#  Test accuracy: 0.547
# Epoch: 174/300 cost: 0.368119072
#  Training accuracy: 0.800
#  Test accuracy: 0.567
# Epoch: 177/300 cost: 0.381239180
#  Training accuracy: 0.800
#  Test accuracy: 0.553
# Epoch: 180/300 cost: 0.409318301
#  Training accuracy: 0.700
#  Test accuracy: 0.553
# Epoch: 183/300 cost: 0.401771555
#  Training accuracy: 0.600
#  Test accuracy: 0.487
# Epoch: 186/300 cost: 0.439259544
#  Training accuracy: 0.700
#  Test accuracy: 0.533
# Epoch: 189/300 cost: 0.373679416
#  Training accuracy: 0.900
#  Test accuracy: 0.567
# Epoch: 192/300 cost: 0.360505390
#  Training accuracy: 0.700
#  Test accuracy: 0.560
# Epoch: 195/300 cost: 0.422421974
#  Training accuracy: 0.900
#  Test accuracy: 0.500
# Epoch: 198/300 cost: 0.390221603
#  Training accuracy: 0.800
#  Test accuracy: 0.560
# Epoch: 201/300 cost: 0.366961413
#  Training accuracy: 0.800
#  Test accuracy: 0.507
# Epoch: 204/300 cost: 0.330407540
#  Training accuracy: 0.800
#  Test accuracy: 0.547
# Epoch: 207/300 cost: 0.340236054
#  Training accuracy: 0.700
#  Test accuracy: 0.480
# Epoch: 210/300 cost: 0.349442360
#  Training accuracy: 0.900
#  Test accuracy: 0.533
# Epoch: 213/300 cost: 0.355452338
#  Training accuracy: 0.900
#  Test accuracy: 0.493
# Epoch: 216/300 cost: 0.303562937
#  Training accuracy: 0.900
#  Test accuracy: 0.533
# Epoch: 219/300 cost: 0.336737466
#  Training accuracy: 1.000
#  Test accuracy: 0.560
# Epoch: 222/300 cost: 0.309040048
#  Training accuracy: 0.900
#  Test accuracy: 0.540
# Epoch: 225/300 cost: 0.353155248
#  Training accuracy: 0.700
#  Test accuracy: 0.547
# Epoch: 228/300 cost: 0.331724793
#  Training accuracy: 0.800
#  Test accuracy: 0.533
# Epoch: 231/300 cost: 0.295804551
#  Training accuracy: 0.900
#  Test accuracy: 0.500
# Epoch: 234/300 cost: 0.285640771
#  Training accuracy: 0.900
#  Test accuracy: 0.540
# Epoch: 237/300 cost: 0.350431188
#  Training accuracy: 0.900
#  Test accuracy: 0.533
# Epoch: 240/300 cost: 0.325596068
#  Training accuracy: 1.000
#  Test accuracy: 0.533
# Epoch: 243/300 cost: 0.316311478
#  Training accuracy: 1.000
#  Test accuracy: 0.480
# Epoch: 246/300 cost: 0.326559389
#  Training accuracy: 0.900
#  Test accuracy: 0.480
# Epoch: 249/300 cost: 0.305533959
#  Training accuracy: 1.000
#  Test accuracy: 0.540
# Epoch: 252/300 cost: 0.259007233
#  Training accuracy: 1.000
#  Test accuracy: 0.560
# Epoch: 255/300 cost: 0.301035829
#  Training accuracy: 0.900
#  Test accuracy: 0.507
# Epoch: 258/300 cost: 0.290568270
#  Training accuracy: 0.800
#  Test accuracy: 0.540
# Epoch: 261/300 cost: 0.277673082
#  Training accuracy: 1.000
#  Test accuracy: 0.513
# Epoch: 264/300 cost: 0.266952756
#  Training accuracy: 0.800
#  Test accuracy: 0.487
# Epoch: 267/300 cost: 0.290651147
#  Training accuracy: 0.900
#  Test accuracy: 0.487
# Epoch: 270/300 cost: 0.251883924
#  Training accuracy: 0.800
#  Test accuracy: 0.533
# Epoch: 273/300 cost: 0.255145987
#  Training accuracy: 0.900
#  Test accuracy: 0.500
# Epoch: 276/300 cost: 0.260315408
#  Training accuracy: 0.900
#  Test accuracy: 0.533
# Epoch: 279/300 cost: 0.254984795
#  Training accuracy: 0.900
#  Test accuracy: 0.520
# Epoch: 282/300 cost: 0.258831513
#  Training accuracy: 0.800
#  Test accuracy: 0.560
# Epoch: 285/300 cost: 0.255540564
#  Training accuracy: 0.800
#  Test accuracy: 0.507
# Epoch: 288/300 cost: 0.266696735
#  Training accuracy: 0.700
#  Test accuracy: 0.547
# Epoch: 291/300 cost: 0.255811818
#  Training accuracy: 0.800
#  Test accuracy: 0.533
# Epoch: 294/300 cost: 0.259823060
#  Training accuracy: 0.900
#  Test accuracy: 0.527
# Epoch: 297/300 cost: 0.221139030
#  Training accuracy: 0.900
#  Test accuracy: 0.527
# Optimization Finished!

# %%
#Let's plot training and testing acurracy across 300 epochs
print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]
# Out:
# 100

# %%
#Let's plot training and testing acurracy across 300 epochs
#print(len(testing))
x = [ i*display_step for i in range(0,len(testing))]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, testing, label="Test Set Accuracy")
ax1.plot(x,training, label="Training Set Accuracy")
ax1.set_ylim([0.,1.])
ax1.set_xlabel("epoch")
ax1.set_ylabel("accuracy")
ax1.set_title("Transfer Learning - < 18 Males - Max Projection by Axis")

handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

fig.suptitle("Batch: %d, lr: %f, derivative: alff" % (batch_size, learning_rate) )
